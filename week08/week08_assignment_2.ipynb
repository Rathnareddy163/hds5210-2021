# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
import requests
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }

response = requests.get('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency', headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
div = soup.find_all('div', {"class":"col-md-8"})[0]
for hospital_list in div.find_all('ul'):
    state = hospital_list.previous_sibling.previous_sibling.string
    for hospital in hospital_list.find_all('li'):
        print(state, hospital.text)
# Out:
# Arizona Banner - University Medical Center Phoenix
# Arizona Banner - University Medical Center South
# Arizona Banner - University Medical Center Tucson
# Arizona Banner Baywood Medical Center
# Arizona Banner Behavioral Health Hospital
# Arizona Banner Boswell Medical Center
# Arizona Banner Casa Grande Medical Center
# Arizona Banner Del E. Webb Medical Center
# Arizona Banner Desert Medical Center/Cardon Children's Medical Center
# Arizona Banner Estrella Medical Center
# Arizona Banner Gateway Medical Center/Banner MD Anderson Cancer Center
# Arizona Banner Goldfield Medical Center
# Arizona Banner Heart Hospital
# Arizona Banner Ironwood Medical Center
# Arizona Banner Ocotillo Medical Center
# Arizona Banner Payson Medical Center
# Arizona Banner Thunderbird Medical Center
# Arizona Page Hospital
# California Banner Lassen Medical Center
# Colorado Banner Fort Collins Medical Center
# Colorado McKee Medical Center
# Colorado North Colorado Medical Center
# Colorado Sterling Regional Medical Center
# Colorado East Morgan County Hospital
# Nebraska Ogallala Community Hospital
# Nevada Banner Churchill Community Hospital
# Wyoming Banner Wyoming Medical Center
# Wyoming Community Hospital
# Wyoming Washakie Medical Center
# Wyoming Platte County Memorial Hospital
# State-Specific Regulations Arizona
# State-Specific Regulations California
# State-Specific Regulations Colorado
# State-Specific Regulations Nebraska
# State-Specific Regulations Nevada
# State-Specific Regulations Wyoming

# %% [markdown]
# ---
#
# ### 33.2 Using Pandas to Read Tables
#
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/Diagnosis-related_group')
len(tables)
# Out:
# 5

# %%
for index,table in enumerate(tables):
    print("**************TABLE {}".format(index))
    print(table)
# Out:
# **************TABLE 0
#     0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. Please updat...
# 2 NaN  This article needs additional citations for ve...
# **************TABLE 1
#     0                                                  1
# 0 NaN  This article needs to be updated. Please updat...
# **************TABLE 2
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...
# **************TABLE 3
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8  \
# 0                                         Description
# 1                              Average length of stay
# 2                      Large urban labor-related rate
# 3                       Large urban non-labor-related
# 4                                          Wage index
# 5   Standard Federal Rate: labor * wage index + no...
# 6                     DRG relative weight (RW) factor
# 7    Weighted payment: Standard Federal Rate * DRG RW
# 8                Disproportionate Share Payment (DSH)
# 9                    Indirect medical education (IME)
# 10                   Total cost outlier reimbursement
# 11  Total operating payment: Weighted payment * (1...
#
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8.1
# 0                                               Value
# 1                                             3.8[16]
# 2                                           $2,809.18
# 3                                           $1,141.85
# 4                                              1.4193
# 5                                           $5,128.92
# 6                                              1.8128
# 7                                           $9,297.71
# 8                                              0.1413
# 9                                              0.0744
# 10                                                 $0
# 11                                         $11,303.23
# **************TABLE 4
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %%
drgs = tables[4]
drgs
# Out:
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Your Code Here
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

# %%
# Make a list of the best fantasy books of the 21st century by compiling the list from the first 10 pages of goodreads.com Fantasy books of the 21st century list

# URL = https://www.goodreads.com/list/show/88.Best_Fantasy_Books_of_the_21st_Century
#url2 = r"https://www.goodreads.com/list/show/88.Best_Fantasy_Books_of_the_21st_Century?page=2"


url_format = r"https://www.goodreads.com/list/show/88.Best_Fantasy_Books_of_the_21st_Century"


urls = []
for i in range(1,28): #maximum range can be 27
    if i ==1:
        urls.append(url_format)
    else:
        urls.append(url_format+str("?page=")+str(i))
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }

# %%
novels, authors, avg_ratings, no_ratings = [], [], [], []
for i in urls:
    #Get HTML Information from URL and create a BS Soup object
    response = requests.get(i, headers=headers)
    soup = bs(response.text, "html.parser")
    el_table = soup.find("table")
    # print(bs.prettify(el_table))
    
    #Find Table sub elements in the table in html
    table_rows = el_table.findChildren("tr" , recursive=False)
    
    #Iterate over each row in table element(Find details for each book)
    for row in table_rows:
        table_cells = row.findChildren("td" , recursive=False)
        info_cell = table_cells[2]
        novel_name = info_cell.findChildren("a")[0].findChildren("span")[0].text
        novels.append(novel_name)
        author = info_cell.findChildren("span", recursive=False)[1].findChild().findChild().findChild().text
        authors.append(author)
        otherinfo = info_cell.find(class_ = "minirating").text
        search = re.findall(r"([\.0123456789]*) avg rating — ([,0123456789]*)", otherinfo)
        avg_rating = float(search[0][0])
        avg_ratings.append(avg_rating)
        ratings = search[0][1]
        ratings = int(ratings.replace(",", ""))
        no_ratings.append(ratings)

# %%
df = pd.DataFrame({"Novel":novels, "Author":authors, "Average_Rating":avg_ratings, "Ratings":no_ratings})
df
# Out:
#                                                   Novel               Author  \
# 0     The Name of the Wind (The Kingkiller Chronicle...     Patrick Rothfuss
# 1     Harry Potter and the Deathly Hallows (Harry Po...         J.K. Rowling
# 2     The Wise Man's Fear (The Kingkiller Chronicle,...     Patrick Rothfuss
# 3     Harry Potter and the Half-Blood Prince (Harry ...         J.K. Rowling
# 4     Harry Potter and the Order of the Phoenix (Har...         J.K. Rowling
# ...                                                 ...                  ...
# 2622  The Immortal Hunter (Argeneau #11; Rogue Hunte...         Lynsay Sands
# 2623     Sixth Grave on the Edge (Charley Davidson, #6)        Darynda Jones
# 2624    Christmas in Transylvania (Deadly Angels, #4.5)          Sandra Hill
# 2625                A Shiver of Light (Merry Gentry #9)  Laurell K. Hamilton
# 2626                           Visions (Cainsville, #2)     Kelley Armstrong
#
#       Average_Rating  Ratings
# 0               4.52   756850
# 1               4.62  2946405
# 2               4.54   450707
# 3               4.57  2564965
# 4               4.50  2642430
# ...              ...      ...
# 2622            4.22    14262
# 2623            4.33    28826
# 2624            4.07      568
# 2625            3.79    14477
# 2626            4.25    11607
#
# [2627 rows x 4 columns]

# %%
#CLean the Dataframe to contain only items if number of ratings are greater than 100,000 and average rating is greater than 4.0
drop_rows = []
for index, row in df.iterrows():
    if row[3] < 100000:
        drop_rows.append(index)
    if row[2] < 4.0:
        drop_rows.append(index)

len(list(set(drop_rows)))
df2 = df.drop(drop_rows)
pd.set_option('display.max_rows', None)
df2.sort_values(by=['Ratings'], ascending=False)

#Export to Excel
# df2.to_excel()
# Out:
#                                                   Novel  \
# 105             The Hunger Games (The Hunger Games, #1)
# 1770                                               1984
# 316                 The Hobbit, or There and Back Again
# 2403  Harry Potter and the Prisoner of Azkaban (Harr...
# 1     Harry Potter and the Deathly Hallows (Harry Po...
# 8     Harry Potter and the Goblet of Fire (Harry Pot...
# 712    The Girl with the Dragon Tattoo (Millennium, #1)
# 102                Catching Fire (The Hunger Games, #2)
# 4     Harry Potter and the Order of the Phoenix (Har...
# 3     Harry Potter and the Half-Blood Prince (Harry ...
# 264                   Mockingjay (The Hunger Games, #3)
# 774   The Fellowship of the Ring (The Lord of the Ri...
# 11    The Lightning Thief (Percy Jackson and the Oly...
# 101      A Game of Thrones (A Song of Ice and Fire, #1)
# 1777         City of Bones (The Mortal Instruments, #1)
# 18           City of Bones (The Mortal Instruments, #1)
# 1759      The Handmaid's Tale (The Handmaid's Tale, #1)
# 1094                          Insurgent (Divergent, #2)
# 2136                    Ender's Game (Ender's Saga, #1)
# 2053              The Maze Runner (The Maze Runner, #1)
# 239             Ready Player One (Ready Player One, #1)
# 36           City of Glass (The Mortal Instruments, #3)
# 30    The Sea of Monsters (Percy Jackson and the Oly...
# 9                     American Gods (American Gods, #1)
# 65    The Battle of the Labyrinth (Percy Jackson and...
# 40           City of Ashes (The Mortal Instruments, #2)
# 0     The Name of the Wind (The Kingkiller Chronicle...
# 31    The Titan's Curse (Percy Jackson and the Olymp...
# 47                                     The Night Circus
# 129                   Cinder (The Lunar Chronicles, #1)
# 24    The Last Olympian (Percy Jackson and the Olymp...
# 46           Clockwork Angel (The Infernal Devices, #1)
# 5        A Storm of Swords (A Song of Ice and Fire, #3)
# 99                Throne of Glass (Throne of Glass, #1)
# 86            The Lost Hero (The Heroes of Olympus, #1)
# 14       A Feast for Crows (A Song of Ice and Fire, #4)
# 522                           Red Queen (Red Queen, #1)
# 170   A Court of Thorns and Roses (A Court of Thorns...
# 227   Good Omens: The Nice and Accurate Prophecies o...
# 16    A Dance with Dragons (A Song of Ice and Fire, #5)
# 145               Vampire Academy (Vampire Academy, #1)
# 28                                             Coraline
# 104                    The Ocean at the End of the Lane
# 2516                             The Shadow of the Wind
# 1741        Clockwork Prince (The Infernal Devices, #2)
# 246      The Mark of Athena (The Heroes of Olympus, #3)
# 20                                   The Graveyard Book
# 173      World War Z: An Oral History of the Zombie War
# 2     The Wise Man's Fear (The Kingkiller Chronicle,...
# 410                       Neverwhere (London Below, #1)
# 2347                Watership Down (Watership Down, #1)
# 109      The Son of Neptune (The Heroes of Olympus, #2)
# 6                       The Final Empire (Mistborn, #1)
# 298                        The Tales of Beedle the Bard
# 1700                        The One (The Selection, #3)
# 1621                                              Circe
# 281   A Court of Mist and Fury (A Court of Thorns an...
# 23                      Graceling (Graceling Realm, #1)
# 144      A Discovery of Witches (All Souls Trilogy, #1)
# 120                     Six of Crows (Six of Crows, #1)
# 205             Crown of Midnight (Throne of Glass, #2)
# 727                                            Stardust
# 363       Clockwork Princess (The Infernal Devices, #3)
# 130           The Red Pyramid (The Kane Chronicles, #1)
# 128                   Shadow Kiss (Vampire Academy, #3)
# 7         The Way of Kings (The Stormlight Archive, #1)
# 85    Daughter of Smoke & Bone (Daughter of Smoke & ...
# 92                                   Kafka on the Shore
# 313                     Frostbite (Vampire Academy, #2)
# 169                  Heir of Fire (Throne of Glass, #3)
# 34                 Brisingr (The Inheritance Cycle, #3)
# 416   A Court of Wings and Ruin (A Court of Thorns a...
# 297                                  The Amber Spyglass
# 953   City of Heavenly Fire (The Mortal Instruments,...
# 25                 The Well of Ascension (Mistborn, #2)
# 2401                               The Song of Achilles
# 800           Dark Lover (Black Dagger Brotherhood, #1)
# 359                The Raven Boys (The Raven Cycle, #1)
# 96                  Blood Promise (Vampire Academy, #4)
# 214      The House of Hades (The Heroes of Olympus, #4)
# 19                      The Hero of Ages (Mistborn, #3)
# 283              Queen of Shadows (Throne of Glass, #4)
# 497                  Spirit Bound (Vampire Academy, #5)
# 566                                        Saga, Vol. 1
# 299                    Red Rising (Red Rising Saga, #1)
# 499                Last Sacrifice (Vampire Academy, #6)
# 324    Harry Potter Series Box Set (Harry Potter, #1-7)
# 2173                                         Snow Crash
# 317                  Crooked Kingdom (Six of Crows, #2)
# 1825           The Testaments (The Handmaid's Tale, #2)
# 934                                  Obsidian (Lux, #1)
# 10     The Lies of Locke Lamora (Gentleman Bastard, #1)
# 238            Wizard's First Rule (Sword of Truth, #1)
# 106             Inheritance (The Inheritance Cycle, #4)
# 1002                          Carry On (Simon Snow, #1)
# 17       Words of Radiance (The Stormlight Archive, #2)
# 1055      The Drawing of the Three (The Dark Tower, #2)
# 613              Empire of Storms (Throne of Glass, #5)
# 438                                         Cloud Atlas
# 140       A Darker Shade of Magic (Shades of Magic, #1)
# 488    The Blood of Olympus (The Heroes of Olympus, #5)
# 943                   Winter (The Lunar Chronicles, #4)
# 513                                Mort (Discworld, #4)
# 2090       Death Note, Vol. 1: Boredom (Death Note, #1)
# 2466            A People's History of the United States
# 788   An Ember in the Ashes (An Ember in the Ashes, #1)
# 39                                          Anansi Boys
# 358             Shadow of Night (All Souls Trilogy, #2)
# 2509                      The Passage (The Passage, #1)
# 799   Ruin and Rising (The Shadow and Bone Trilogy, #3)
# 167              Definitely Dead (Sookie Stackhouse #6)
# 1049               The Waste Lands (The Dark Tower, #3)
# 437                             Sabriel (Abhorsen,  #1)
# 200           All Together Dead (Sookie Stackhouse, #7)
# 22                              Elantris (Elantris, #1)
# 1955          The Wicked King (The Folk of the Air, #2)
# 342                    Moon Called (Mercy Thompson, #1)
# 1864             Lady Midnight (The Dark Artifices, #1)
# 122                                            Uprooted
# 203          From Dead to Worse (Sookie Stackhouse, #8)
# 683        Lover Eternal (Black Dagger Brotherhood, #2)
# 2348                              Champion (Legend, #3)
# 15                 The Blade Itself (The First Law, #1)
# 673      Guards! Guards! (Discworld, #8; City Watch #1)
# 888   Children of Blood and Bone (Legacy of Orïsha, #1)
# 509            Angelfall (Penryn & the End of Days, #1)
# 361                         Bloodlines (Bloodlines, #1)
# 254        The Throne of Fire (The Kane Chronicles, #2)
# 1982              Wizard and Glass (The Dark Tower, #4)
# 79                    Fool Moon (The Dresden Files, #2)
# 185             The Fifth Season (The Broken Earth, #1)
# 741                              The Tale of Despereaux
# 63                           Fire (Graceling Realm, #2)
# 2151                            Wool Omnibus (Silo, #1)
# 418                               Darkfever (Fever, #1)
# 757       Lover Awakened (Black Dagger Brotherhood, #3)
# 76             Wolves of the Calla (The Dark Tower, #5)
# 1838               Kingdom of Ash (Throne of Glass, #7)
# 1010               Kingdom of Ash (Throne of Glass, #7)
# 2454            The Dream Thieves (The Raven Cycle, #2)
# 193                      Steelheart (The Reckoners, #1)
# 765    The Assassin's Blade (Throne of Glass, #0.1-0.5)
# 48                  The Dark Tower (The Dark Tower, #7)
# 21                 The Way of Shadows (Night Angel, #1)
# 1031     The Queen of Nothing (The Folk of the Air, #3)
# 250   Artemis Fowl and the Lost Colony (Artemis Fowl...
# 58                             Poison Study (Study, #1)
# 1983           The Book of Life (All Souls Trilogy, #3)
# 997                          Ignite Me (Shatter Me, #3)
# 587                           Midnight Sun [2008 Draft]
# 549        His Dark Materials (His Dark Materials #1-3)
# 614   Days of Blood & Starlight (Daughter of Smoke &...
# 516                     The Alloy of Law (Mistborn, #4)
# 132                 Grave Peril (The Dresden Files, #3)
# 290            Oathbringer (The Stormlight Archive, #3)
# 206                                     House of Leaves
# 146                         Fablehaven (Fablehaven, #1)
# 74             The Goose Girl (The Books of Bayern, #1)
# 353   The Bear and the Nightingale (The Winternight ...
# 187   Artemis Fowl and the Opal Deception (Artemis F...
# 142               Summer Knight (The Dresden Files, #4)
# 43         The Gathering Storm (The Wheel of Time, #12)
# 569      The Serpent's Shadow (The Kane Chronicles, #3)
# 77          Towers of Midnight (The Wheel of Time, #13)
# 286       The Ruins of Gorlan (Ranger's Apprentice, #1)
# 158                The Eternity Code (Artemis Fowl, #3)
# 2446         Blue Lily, Lily Blue (The Raven Cycle, #3)
# 1899                                  Crank (Crank, #1)
# 52                          Warbreaker (Warbreaker, #1)
# 1736  The Wrath and the Dawn (The Wrath and the Dawn...
# 523              The Power of Six (Lorien Legacies, #2)
# 220   Harry Potter and the Order of the Phoenix (Har...
# 935       Lover Revealed (Black Dagger Brotherhood, #4)
# 189                 Death Masks (The Dresden Files, #5)
# 1971       Lover Unbound (Black Dagger Brotherhood, #5)
# 706        The Hidden Oracle (The Trials of Apollo, #1)
# 32           Before They Are Hanged (The First Law, #2)
# 312               Ruby Red (Precious Stone Trilogy, #1)
# 33             The Amulet of Samarkand (Bartimaeus, #1)
# 676        A Gathering of Shadows (Shades of Magic, #2)
# 107                             Abhorsen (Abhorsen, #3)
# 38     Red Seas Under Red Skies (Gentleman Bastard, #2)
# 204                 Blood Rites (The Dresden Files, #6)
# 37           Last Argument of Kings (The First Law, #3)
# 141                Dead Witch Walking (The Hollows, #1)
# 1003                       Ninth House (Alex Stern, #1)
# 152                    Blood Bound (Mercy Thompson, #2)
# 68           A Memory of Light (The Wheel of Time, #14)
# 1028  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 111                   Dead Beat (The Dresden Files, #7)
# 27                     The Warded Man (Demon Cycle, #1)
# 95                                Lirael (Abhorsen, #2)
# 1030               The Raven King (The Raven Cycle, #4)
# 1922          Rise of the Evening Star (Fablehaven, #2)
# 1848                      A Dirty Job (Grim Reaper, #1)
# 984              The Year of the Flood  (MaddAddam, #2)
# 732                    The Golden Lily (Bloodlines, #2)
# 479                      Magic Bites (Kate Daniels, #1)
# 97              Princess Academy (Princess Academy, #1)
# 1017                    The Talisman (The Talisman, #1)
# 962                               Redwall (Redwall, #1)
# 1816                Stone of Tears (Sword of Truth, #2)
# 211               Proven Guilty (The Dresden Files, #8)
# 240   The Golem and the Jinni (The Golem and the Jin...
# 1938     Lover Enshrined (Black Dagger Brotherhood, #6)
# 291                 White Night (The Dresden Files, #9)
# 2615  A Torch Against the Night (An Ember in the Ash...
# 50                   The Black Prism (Lightbringer, #1)
# 59             Knife of Dreams (The Wheel of Time, #11)
# 1484                                          Heartless
# 1703           Lord of Shadows (The Dark Artifices, #2)
# 2018       The Burning Bridge (Ranger's Apprentice, #2)
# 390                                   The Scorpio Races
# 1903            Black Butler, Vol. 1 (Black Butler, #1)
# 1083            The Obelisk Gate (The Broken Earth, #2)
# 54                     Changes (The Dresden Files, #12)
# 2303  The Gentleman's Guide to Vice and Virtue (Mont...
# 2211                                      Cryptonomicon
# 2341                  The Iron Queen (The Iron Fey, #3)
# 78                 Furies of Calderon (Codex Alera, #1)
#
#                       Author  Average_Rating  Ratings
# 105          Suzanne Collins            4.32  6661813
# 1770           George Orwell            4.19  3345894
# 316           J.R.R. Tolkien            4.28  3033444
# 2403            J.K. Rowling            4.57  2988892
# 1               J.K. Rowling            4.62  2946405
# 8               J.K. Rowling            4.56  2737987
# 712            Stieg Larsson            4.14  2712831
# 102          Suzanne Collins            4.29  2650503
# 4               J.K. Rowling            4.50  2642430
# 3               J.K. Rowling            4.57  2564965
# 264          Suzanne Collins            4.05  2462742
# 774           J.R.R. Tolkien            4.37  2435012
# 11              Rick Riordan            4.26  2114412
# 101       George R.R. Martin            4.44  2078874
# 1777         Cassandra Clare            4.09  1687032
# 18           Cassandra Clare            4.09  1687032
# 1759         Margaret Atwood            4.12  1551163
# 1094           Veronica Roth            4.02  1222464
# 2136        Orson Scott Card            4.30  1175057
# 2053           James Dashner            4.03  1130036
# 239             Ernest Cline            4.25   923198
# 36           Cassandra Clare            4.30   831509
# 30              Rick Riordan            4.24   800804
# 9                Neil Gaiman            4.10   791109
# 65              Rick Riordan            4.39   786789
# 40           Cassandra Clare            4.15   786494
# 0           Patrick Rothfuss            4.52   756850
# 31              Rick Riordan            4.34   734672
# 47          Erin Morgenstern            4.03   729173
# 129            Marissa Meyer            4.13   726345
# 24              Rick Riordan            4.50   713509
# 46           Cassandra Clare            4.31   706229
# 5         George R.R. Martin            4.53   684657
# 99             Sarah J. Maas            4.20   664051
# 86              Rick Riordan            4.32   662446
# 14        George R.R. Martin            4.14   646454
# 522         Victoria Aveyard            4.04   621957
# 170            Sarah J. Maas            4.21   578366
# 227          Terry Pratchett            4.24   575338
# 16        George R.R. Martin            4.32   574566
# 145            Richelle Mead            4.11   572358
# 28               Neil Gaiman            4.05   515509
# 104              Neil Gaiman            4.00   503760
# 2516       Carlos Ruiz Zafón            4.27   493247
# 1741         Cassandra Clare            4.43   468796
# 246             Rick Riordan            4.44   465699
# 20               Neil Gaiman            4.13   459451
# 173               Max Brooks            4.01   458109
# 2           Patrick Rothfuss            4.54   450707
# 410              Neil Gaiman            4.16   447048
# 2347          Richard  Adams            4.06   445434
# 109             Rick Riordan            4.42   440199
# 6          Brandon Sanderson            4.44   434527
# 298             J.K. Rowling            4.05   428241
# 1700              Kiera Cass            4.19   423762
# 1621         Madeline Miller            4.26   421041
# 281            Sarah J. Maas            4.61   406373
# 23           Kristin Cashore            4.07   403983
# 144         Deborah Harkness            4.00   399436
# 120            Leigh Bardugo            4.43   386903
# 205            Sarah J. Maas            4.40   385453
# 727              Neil Gaiman            4.08   375386
# 363          Cassandra Clare            4.55   364203
# 130             Rick Riordan            4.08   338696
# 128            Richelle Mead            4.33   338081
# 7          Brandon Sanderson            4.61   332248
# 85              Laini Taylor            4.00   329938
# 92           Haruki Murakami            4.13   328242
# 313            Richelle Mead            4.26   323248
# 169            Sarah J. Maas            4.46   321148
# 34       Christopher Paolini            4.05   317650
# 416            Sarah J. Maas            4.44   315869
# 297           Philip Pullman            4.08   315790
# 953          Cassandra Clare            4.41   311577
# 25         Brandon Sanderson            4.35   307012
# 2401         Madeline Miller            4.39   302182
# 800                J.R. Ward            4.17   301201
# 359        Maggie Stiefvater            4.04   291497
# 96             Richelle Mead            4.30   288546
# 214             Rick Riordan            4.52   286974
# 19         Brandon Sanderson            4.48   284958
# 283            Sarah J. Maas            4.54   277472
# 497            Richelle Mead            4.33   269664
# 566         Brian K. Vaughan            4.18   268025
# 299             Pierce Brown            4.24   266917
# 499            Richelle Mead            4.37   264309
# 324             J.K. Rowling            4.72   259866
# 2173         Neal Stephenson            4.02   243106
# 317            Leigh Bardugo            4.58   242731
# 1825         Margaret Atwood            4.20   242399
# 934   Jennifer L. Armentrout            4.16   242167
# 10               Scott Lynch            4.26   239740
# 238           Terry Goodkind            4.11   234636
# 106      Christopher Paolini            4.09   229163
# 1002          Rainbow Rowell            4.21   228552
# 17         Brandon Sanderson            4.74   226997
# 1055            Stephen King            4.21   226419
# 613            Sarah J. Maas            4.53   226277
# 438           David Mitchell            4.00   225911
# 140              V.E. Schwab            4.07   224780
# 488             Rick Riordan            4.41   219876
# 943            Marissa Meyer            4.43   211410
# 513          Terry Pratchett            4.21   207382
# 2090            Tsugumi Ohba            4.44   204747
# 2466             Howard Zinn            4.06   204674
# 788              Sabaa Tahir            4.26   204432
# 39               Neil Gaiman            4.02   201711
# 358         Deborah Harkness            4.05   198096
# 2509           Justin Cronin            4.03   196947
# 799            Leigh Bardugo            4.07   196841
# 167         Charlaine Harris            4.00   196841
# 1049            Stephen King            4.22   194407
# 437                Garth Nix            4.14   193940
# 200         Charlaine Harris            4.04   191484
# 22         Brandon Sanderson            4.17   189919
# 1955             Holly Black            4.36   188314
# 342          Patricia Briggs            4.13   186290
# 1864         Cassandra Clare            4.38   183895
# 122              Naomi Novik            4.05   182773
# 203         Charlaine Harris            4.00   179245
# 683                J.R. Ward            4.33   176953
# 2348                Marie Lu            4.33   176493
# 15           Joe Abercrombie            4.16   176220
# 673          Terry Pratchett            4.29   175416
# 888             Tomi Adeyemi            4.10   175093
# 509                 Susan Ee            4.12   174897
# 361            Richelle Mead            4.19   174882
# 254             Rick Riordan            4.18   174826
# 1982            Stephen King            4.23   174349
# 79               Jim Butcher            4.00   171434
# 185             N.K. Jemisin            4.28   170645
# 741           Kate DiCamillo            4.04   170322
# 63           Kristin Cashore            4.09   169367
# 2151              Hugh Howey            4.20   166778
# 418       Karen Marie Moning            4.06   165909
# 757                J.R. Ward            4.44   165101
# 76              Stephen King            4.16   164503
# 1838           Sarah J. Maas            4.57   162225
# 1010           Sarah J. Maas            4.57   162225
# 2454       Maggie Stiefvater            4.21   161074
# 193        Brandon Sanderson            4.13   158973
# 765            Sarah J. Maas            4.37   156290
# 48              Stephen King            4.24   154523
# 21               Brent Weeks            4.13   154207
# 1031             Holly Black            4.35   153534
# 250              Eoin Colfer            4.00   152667
# 58           Maria V. Snyder            4.09   152420
# 1983        Deborah Harkness            4.17   150350
# 997             Tahereh Mafi            4.39   150135
# 587          Stephenie Meyer            4.01   149758
# 549           Philip Pullman            4.25   149719
# 614             Laini Taylor            4.14   147946
# 516        Brandon Sanderson            4.20   146887
# 132              Jim Butcher            4.14   146174
# 290        Brandon Sanderson            4.58   146118
# 206      Mark Z. Danielewski            4.05   142352
# 146             Brandon Mull            4.09   141343
# 74              Shannon Hale            4.10   139718
# 353          Katherine Arden            4.09   136476
# 187              Eoin Colfer            4.03   134476
# 142              Jim Butcher            4.26   134259
# 43             Robert Jordan            4.36   133361
# 569             Rick Riordan            4.27   131037
# 77             Robert Jordan            4.41   130949
# 286            John Flanagan            4.21   130885
# 158              Eoin Colfer            4.02   130556
# 2446       Maggie Stiefvater            4.25   130038
# 1899           Ellen Hopkins            4.15   129483
# 52         Brandon Sanderson            4.26   128976
# 1736            Renée Ahdieh            4.10   128204
# 523            Pittacus Lore            4.15   127278
# 220             J.K. Rowling            4.62   126934
# 935                J.R. Ward            4.29   125125
# 189              Jim Butcher            4.28   123828
# 1971               J.R. Ward            4.32   123407
# 706             Rick Riordan            4.20   123315
# 32           Joe Abercrombie            4.29   123243
# 312             Kerstin Gier            4.09   121622
# 33           Jonathan Stroud            4.00   121202
# 676              V.E. Schwab            4.25   120194
# 107                Garth Nix            4.20   119795
# 38               Scott Lynch            4.22   119142
# 204              Jim Butcher            4.29   117330
# 37           Joe Abercrombie            4.27   116020
# 141             Kim Harrison            4.02   115347
# 1003           Leigh Bardugo            4.04   114921
# 152          Patricia Briggs            4.30   114897
# 68             Robert Jordan            4.50   114586
# 1028          J.R.R. Tolkien            4.60   114294
# 111              Jim Butcher            4.39   113916
# 27            Peter V. Brett            4.23   113606
# 95                 Garth Nix            4.25   113351
# 1030       Maggie Stiefvater            4.23   112975
# 1922            Brandon Mull            4.16   112952
# 1848       Christopher Moore            4.02   112652
# 984          Margaret Atwood            4.04   112466
# 732            Richelle Mead            4.30   112184
# 479            Ilona Andrews            4.04   111653
# 97              Shannon Hale            4.00   111513
# 1017            Stephen King            4.13   110212
# 962            Brian Jacques            4.10   109417
# 1816          Terry Goodkind            4.09   109250
# 211              Jim Butcher            4.38   109213
# 240            Helene Wecker            4.08   108920
# 1938               J.R. Ward            4.12   108638
# 291              Jim Butcher            4.37   108249
# 2615             Sabaa Tahir            4.25   108087
# 50               Brent Weeks            4.21   107068
# 59             Robert Jordan            4.14   106707
# 1484           Marissa Meyer            4.04   106189
# 1703         Cassandra Clare            4.46   106072
# 2018           John Flanagan            4.31   105805
# 390        Maggie Stiefvater            4.06   104176
# 1903             Yana Toboso            4.37   103884
# 1083            N.K. Jemisin            4.28   103435
# 54               Jim Butcher            4.49   102008
# 2303            Mackenzi Lee            4.08   101698
# 2211         Neal Stephenson            4.24   101475
# 2341            Julie Kagawa            4.20   100950
# 78               Jim Butcher            4.10   100720

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-cef8011cb395> in <module>
# ----> 1 assert False, "DO NOT REMOVE THIS LINE"
#
# AssertionError: DO NOT REMOVE THIS LINE

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week08_assignment_2.ipynb
# git commit -a -m "Submitting the week 8 programming assignment"
# git push

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 8 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
